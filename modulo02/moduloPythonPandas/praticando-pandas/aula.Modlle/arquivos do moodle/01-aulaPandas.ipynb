# %%
import pandas as pd

dados = pd.Series([10,9,8,3,4])

print(dados)
# Out:
# 0    10
# 1     9
# 2     8
# 3     3
# 4     4
# dtype: int64

# %% [markdown]
# # Nova seção

# %%
import pandas as pd

gols_sofridos = pd.Series([1,2,3,4,5], index=['R1', 'R2','R3','R4','R5'])

print(gols_sofridos)
# Out:
# R1    1
# R2    2
# R3    3
# R4    4
# R5    5
# dtype: int64

# %% [markdown]
# dataFreme

# %%
import pandas as pd

dados= {
    'times':['Fla','Cor','Bot'],
    'Gol': [5,8,4]
}

tabela= pd.DataFrame(dados)
print(tabela)
# Out:
#   times  Gol
# 0   Fla    5
# 1   Cor    8
# 2   Bot    4

# %%
import pandas as pd

jogador={
    'Jogados':['joao',"messi",'CR7'],
    'Times':['Flam','Barça','Real']
}

joga = pd.DataFrame(jogador)
print(joga)
# Out:
#   Jogados  Times
# 0    joao   Flam
# 1   messi  Barça
# 2     CR7   Real

# %% [markdown]
# Leitura de arquivo

# %%
#Gravando arquivos CSV
import pandas as pd

campeonato = pd.read_csv('')

print(campeonato.head(5))#.head = diz quantos

#Cliente que so ve os os
relatorio = [['Jogo','Gols_Time','Gol_Adversario']]
print(relatorio)

relatorio.pd.to_csv('relatorio.csv', index=False)#index=False: 0,1,2 eles nao aparecem no relatorio
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-25-43533ac85f7b> in <cell line: 0>()
#       2 import pandas as pd
#       3
# ----> 4 campeonato = pd.read_csv('')
#       5
#       6 print(campeonato.head(5))#.head = diz quantos
#
# ...

# %% [markdown]
# Exercio 01-Crie uma Series representando a quantidade de gols marcados pelo seu
# time favorito nas últimas 5 partidas.

# %%
import pandas as pd

time = pd.Series([3,2,5,1,2], index=['Jogo 01','Jogo 02','Jogo 03','Jogo 04','jogo 05'])

print(time)
# Out:
# Jogo 01    3
# Jogo 02    2
# Jogo 03    5
# Jogo 04    1
# jogo 05    2
# dtype: int64

# %% [markdown]
# 02 - Crie um DataFrame com 4 times do Brasileirão e suas estatísticas de
# vitórias, empates e derrotas.

# %%
import pandas as pd

brasileirao = {
    'Times':['Flamengo', 'Gremio', 'Vasco', 'Botafogo'],
    'Vitorias':[7,3,1,5],
    'Empates':[2,5,8,3],
    'Derrotas':[1,2,1,2]
}

relatorio = pd.DataFrame(brasileirao)
print(relatorio)

relatorio.to_csv('Tabela_campeonato.csv', index=False)
# Out:
#       Times  Vitorias  Empates  Derrotas
# 0  Flamengo         7        2         1
# 1    Gremio         3        5         2
# 2     Vasco         1        8         1
# 3  Botafogo         5        3         2

# %% [markdown]
# 3 - Salve o DataFrame em um arquivo CSV e carregue-o novamente.
# Se precisar de ajuda, volte nesta lição e revise os exemplos!

# %%
import pandas as pd

campeonato = pd.read_csv('//campeonato.csv')

print(campeonato)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-15f8dd42a2c3> in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 campeonato = pd.read_csv('//campeonato.csv')
#       4
#       5 print(campeonato)
#
# ...

# %% [markdown]
# Hello trazer

# %%
import pandas as pd

pagamentos = pd.read_csv('/content/Adalto 16_01_2025 - Página1.csv')
pg_filtrado = pagamentos[pagamentos['Situação'] == 'Aguardando Pagamento']
print(pg_filtrado)

pg_filtrado.to_excel('Contas_a_receber.xlsx', index=False)
# Out:
#                           Nome  \
# 1                      Tatiane
# 3                      Eurides
# 4                       Dayane
# 5                       Naiane
# 9                  Ana de Davi
# 11              Francisca CICI
# 15                       Leila
# 16  Carla (Cunhada de Tatiana)
# 20                      Erilda
# 26                    Raimunda
# 27                  Socorrinha
# 28                     cachica
# 31                     Glaucia
# 33              Maria Enedina
# 34                    Aristela
# 35               Maria branca
# 42                     marlene
# 43                     eurides
# 44                      andrea
# 45                       wilca
# 46                      Samira
#
#                                             Descrição        Data  \
# 1   07 - Panos de Prato | 01 - Lençol solteiro alg...  16/10/2024
# 3                                         01 - Toalha  16/10/2024
# ...
